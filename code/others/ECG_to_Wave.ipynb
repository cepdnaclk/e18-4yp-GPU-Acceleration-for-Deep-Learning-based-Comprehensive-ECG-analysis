# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from PIL import Image

# # Load the data from the file
# file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/"

# data = np.loadtxt(file_path)

# # Remove the first 300 and last 200 rows
# data = data[300:-200, :]

# # Select a single column with the 4500 rows
# selected_column = data[:, 0]

# # Reshape the data into a 3x3 grid of 1s time intervals
# grid_size = (3, 3)
# time_interval = 500  # 1s in milliseconds should be 1000
# grid_data = selected_column[:time_interval * np.prod(grid_size)].reshape((*grid_size, time_interval))

# # Create an image of the waveform
# fig, axs = plt.subplots(*grid_size, figsize=(9, 9))

# for i in range(grid_size[0]):
#     for j in range(grid_size[1]):
#         axs[i, j].imshow(grid_data[i, j].reshape(-1, 1), cmap='gray')
#         axs[i, j].axis('off')

# plt.subplots_adjust(wspace=0, hspace=0)
# plt.savefig('ecg_waveform.png', bbox_inches='tight', pad_inches=0, transparent=True)

# # Optional: Display the image
# image = Image.open('ecg_waveform.png')
# image.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
data = data[:, 0] # Selecting first lead
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Save the resulting image
plt.savefig('ecg_grid_lead_1.png', dpi=300, bbox_inches='tight')
plt.show()
plt.close()


print("ECG waveform grid saved as 'ecg_grid_lead_1.png'")
# Out:
# ECG waveform grid saved as 'ecg_grid_lead_1.png'

# %%
import numpy as np
import matplotlib.pyplot as plt


# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Convert the grid data to grayscale (average of RGB channels)
# gray_grid_data = np.mean(grid_data, axis=2)
gray_grid_data = grid_data

# Print the grayscale values as a 2D matrix
print("Grayscale matrix:")
print(gray_grid_data)
print("Shape : ", gray_grid_data.shape)

# Save the resulting image
plt.savefig('ecg_grid.png', dpi=256, bbox_inches='tight')
plt.show()
plt.close()

print("ECG waveform grid saved as 'ecg_grid.png'")
# Out:
# Grayscale matrix:
# [[[  18.  -43.  -24. ... -101.  154.    5.]
#   [  12. -117.  -35. ...  -72.   31.  -61.]
#   [ -11.   23.    7. ... -279. -186. -195.]]
#
#  [[ -39.  -75.  -15. ... -386. -280. -268.]
#   [ -34. -101.  -70. ...  -88. -109. -116.]
#   [ -67. -250.   82. ...  -87.  -98.  -85.]]
#
#  [[  -3.   -5.  -13. ...  -32.  -22.  -22.]
#   [ -22.   -4.    9. ...  -47.  -23.  -30.]
#   [ -31.   -2.   37. ...  -16.    3.   15.]]]
# Shape :  (3, 3, 4000)
# ECG waveform grid saved as 'ecg_grid.png'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Convert the grid data to grayscale (average of RGB channels)
gray_grid_data = np.mean(grid_data, axis=2)
# gray_grid_data = grid_data

# Print the grayscale values as a 2D matrix
print("Grayscale matrix:")
print(gray_grid_data)
print("Shape : ", gray_grid_data.shape)

# Save the resulting image
plt.savefig('ecg_grid.png', dpi=256, bbox_inches='tight')
plt.show()
plt.close()

print("ECG waveform grid saved as 'ecg_grid.png'")
# Out:
# Grayscale matrix:
# [[ -32.065    -21.12675  -15.76675]
#  [-127.526    -77.85275  -14.70825]
#  [  -7.1445    -5.13125  -21.2235 ]]
# Shape :  (3, 3)
# ECG waveform grid saved as 'ecg_grid.png'

# %%
import numpy as np
from PIL import Image

# Open the RGBA image
image_path = '/content/ecg_grid.png'
rgba_image = Image.open(image_path)

# Convert RGBA to grayscale
gray_image = rgba_image.convert('L')

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)

# Save the resulting grayscale image
output_path = '/content/ecg_grid_gray.png'
resized_image.save(output_path)

print(f"Grayscale image saved at: {output_path}")
# Out:
# 256x256 Grayscale Image Matrix:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Grayscale image saved at: /content/ecg_grid_gray.png

# %%
import numpy as np
from PIL import Image

# Open the RGBA image
image_path = '/content/ecg_grid_lead_1.png'
rgba_image = Image.open(image_path)

# Convert RGBA to grayscale
gray_image = rgba_image.convert('L')

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)

# Save the resulting grayscale image
output_path = '/content/ecg_grid_gray_lead_1.png'
resized_image.save(output_path)

print(f"Grayscale image saved at: {output_path}")
# Out:
# 256x256 Grayscale Image Matrix:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Grayscale image saved at: /content/ecg_grid_gray_lead_1.png

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
data = data[:, 0]  # Selecting the first lead
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Convert the plot to an RGBA image
fig.canvas.draw()
rgba_image = Image.frombytes('RGBA', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())

# Convert RGBA to grayscale
gray_image = rgba_image.convert('L')

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-d3d9c712c4d4> in <cell line: 36>()
#      34 # Convert the plot to an RGBA image
#      35 fig.canvas.draw()
# ---> 36 rgba_image = Image.frombytes('RGBA', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())
#      37
#      38 # Convert RGBA to grayscale
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2967
#    2968     im = new(mode, size)
# -> 2969     im.frombytes(data, decoder_name, args)
#    2970     return im
#    2971
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     828         if s[0] >= 0:
#     829             msg = "not enough image data"
# --> 830             raise ValueError(msg)
#     831         if s[1] != 0:
#     832             msg = "cannot decode image data"
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
data = data[:, 0]  # Selecting the first lead
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Convert the plot to a grayscale image
fig.canvas.draw()
gray_image = Image.frombytes('L', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)

# Save the resulting grayscale image
output_path = '/content/ecg_grid_gray_lead_1_final.png'
resized_image.save(output_path)

print(f"Grayscale image saved at: {output_path}")
# Out:
# 256x256 Grayscale Image Matrix:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# Grayscale image saved at: /content/ecg_grid_gray_lead_1_final.png

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
data = data[:, 0]  # Selecting the first lead
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Convert the plot to a grayscale image
fig.canvas.draw()
gray_image = Image.frombytes('L', fig.canvas.get_width_height(), fig.canvas.tostring_rgb())

# Close the plot to prevent it from being displayed
plt.close()

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)

# Load the grayscale image directly
image_array = np.array(resized_image)

# Print the pixel values
print(image_array)
# Out:
# 256x256 Grayscale Image Matrix:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"

data = np.loadtxt(file_path)
data = data[:, 0]  # Selecting the first lead
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Create a figure with subplots
# fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
# fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
# for i in range(num_rows):
#     for j in range(num_cols):
#         axs[i, j].plot(grid_data[i, j], color='black')
#         axs[i, j].axis('off')  # Remove axes
#         axs[i, j].set_xticks([])
#         axs[i, j].set_yticks()

# Convert the plot to a grayscale image
# fig.canvas.draw()
gray_image = Image.frombytes('L', (num_cols * 256, num_rows * 256), grid_data.astype(np.uint8).tobytes())

# Resize to 256x256
resized_image = gray_image.resize((256, 256))

# Convert the resized image to a NumPy array
image_matrix = np.array(resized_image)

# Print the matrix values
print("256x256 Grayscale Image Matrix:")
print(image_matrix)

# Load the grayscale image directly
image_array = np.array(resized_image)

# Print the pixel values
print(image_array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a002fb4d2741> in <cell line: 36>()
#      34 # Convert the plot to a grayscale image
#      35 # fig.canvas.draw()
# ---> 36 gray_image = Image.frombytes('L', (num_cols * 256, num_rows * 256), grid_data.astype(np.uint8).tobytes())
#      37
#      38 # Resize to 256x256
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in frombytes(mode, size, data, decoder_name, *args)
#    2967
#    2968     im = new(mode, size)
# -> 2969     im.frombytes(data, decoder_name, args)
#    2970     return im
#    2971
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in frombytes(self, data, decoder_name, *args)
#     828         if s[0] >= 0:
#     829             msg = "not enough image data"
# --> 830             raise ValueError(msg)
#     831         if s[1] != 0:
# ...

# %%
# prompt: Give a code to load the file '/content/ecg_grid_gray.png' and print the pixel values

# Load the grayscale image
image = Image.open('/content/ecg_grid_gray.png')

# Convert to numpy array
image_array = np.array(image)

# Print the pixel values
print(image_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
# prompt: Give a code to load the file '/content/ecg_grid_gray.png' and print the pixel values

# Load the grayscale image
image = Image.open('/content/ecg_grid_gray_lead_1.png')

# Convert to numpy array
image_array = np.array(image)

# Print the pixel values
print(image_array)
# Out:
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
# prompt: Given the png image "/content/ecg_grid.png" give a code to print the pixel values.

import numpy as np
from PIL import Image

# Open the image
image = Image.open('/content/ecg_grid.png')

# Get the pixel values
pixels = np.array(image)

pixels.shape
# Out:
# (1825, 1836, 4)

# %%
# prompt: Given the png image "/content/ecg_grid.png" give a code save the pixel values in a text file named ecg_grid_pixels.txt

# Save the pixel values to a text file
np.savetxt('/content/ecg_grid_pixels.txt', pixels, fmt='%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5208b79305c5> in <cell line: 4>()
#       2
#       3 # Save the pixel values to a text file
# ----> 4 np.savetxt('/content/ecg_grid_pixels.txt', pixels, fmt='%d')
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in savetxt(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1535         # Handle 1-dimensional arrays
#    1536         if X.ndim == 0 or X.ndim > 2:
# -> 1537             raise ValueError(
#    1538                 "Expected 1D or 2D array, got %dD array instead" % X.ndim)
#    1539         elif X.ndim == 1:
#
# ValueError: Expected 1D or 2D array, got 3D array instead

# %%
import numpy as np

grayscale_matrix = np.array(gray_grid_data)

# Set the print options to display more elements in the matrix
np.set_printoptions(threshold=np.inf, precision=2, suppress=True)

# Print the formatted grayscale matrix
print("Grayscale matrix:")
print(grayscale_matrix)
# Out:
# Grayscale matrix:
# [[[   18.   -43.   -24.  -178.   -41.  -188.   203.    73.    28.   -26.
#      -27.  -170.   -46.  -185.   208.   101.    32.   -37.   -45.  -178.
#      -30.  -186.   216.   106.    11.   -55.   -34.  -184.   -25.  -176.
#      212.    86.    11.   -60.   -20.  -177.   -42.  -191.   207.    96.
#        3.   -68.   -15.  -187.   -37.  -179.   209.    94.     4.   -74.
#        0.  -179.   -33.  -162.   208.   107.    16.   -75.     2.  -180.
#      -43.  -171.   228.   116.    13.   -78.     5.  -190.   -42.  -160.
#      229.   107.     6.   -78.     7.  -184.   -65.  -169.   231.   104.
#        6.   -91.     1.  -195.   -66.  -175.   232.    98.     0.   -92.
#       -1.  -204.   -70.  -178.   228.   102.    11.   -71.   -11.  -199.
#      -72.  -184.   224.   107.     5.   -72.    -2.  -196.   -53.  -177.
#      224.   103.     5.   -69.    -1.  -184.   -34.  -176.   225.    99.
#        4.   -73.     4.  -180.   -32.  -177.   221.    93.    13.   -66.
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


# Strip the first 300 and last 200 rows
# Load the data from the file
file_path = "/content/drive/MyDrive/0.asc"

data = np.loadtxt(file_path)
ecg_data = data[300:-200]

# Reshape the data into a 3x3 grid
num_rows = 3
num_cols = 3
grid_data = ecg_data.reshape(num_rows, num_cols, -1)

# Convert the grid data to grayscale (average of RGB channels)
gray_grid_data = np.mean(grid_data, axis=2)

# Print the grayscale values as a 2D matrix
print("Grayscale matrix:")
for row in gray_grid_data:
    print(" ".join(f"{val:.2f}" for val in row))

# Create a figure with subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(9, 9))
fig.subplots_adjust(hspace=0, wspace=0)

# Plot each waveform in grayscale
for i in range(num_rows):
    for j in range(num_cols):
        axs[i, j].plot(grid_data[i, j], color='black')
        axs[i, j].axis('off')  # Remove axes
        axs[i, j].set_xticks([])
        axs[i, j].set_yticks([])

# Save the resulting image
plt.savefig('ecg_grid.png', dpi=256, bbox_inches='tight')
plt.show()
plt.close()

print("ECG waveform grid saved as 'ecg_grid.png'")
# Out:
# Grayscale matrix:
# -32.06 -21.13 -15.77
# -127.53 -77.85 -14.71
# -7.14 -5.13 -21.22
# ECG waveform grid saved as 'ecg_grid.png'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Remove the first 250 and last 250 rows from each column
ecg_data_trimmed = ecg_data[300:-200, :]

# Define the time axis for trimmed data (assuming 2 ms intervals)
time_axis_trimmed = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.002)

# Number of 3-second intervals (1500 rows per interval)
num_intervals = ecg_data_trimmed.shape[0] // 1500

# Create a figure and axis for each lead
for lead_index in range(ecg_data_trimmed.shape[1]):
    fig, axs = plt.subplots(3, 3, figsize=(10, 10), sharex=True, sharey=True)

    # Plot each lead for each 3-second interval in the same image
    for interval_index in range(num_intervals):
        start_row = interval_index * 1500
        end_row = start_row + 1500

        ax = axs[interval_index // 3, interval_index % 3]
        ax.plot(
            time_axis_trimmed[start_row:end_row],
            ecg_data_trimmed[start_row:end_row, lead_index],
            color='black'
        )
        ax.set_title(f'Interval {interval_index + 1}')
        ax.set_ylabel('Amplitude')

    # Set common x-axis label
    axs[-1, 0].set_xlabel('Time (s)')

    # Set x-axis markers every 500 ms
    marker_positions = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.5)
    plt.xticks(marker_positions)

    # Save the figure as a gray scale image
    plt.tight_layout()
    plt.savefig(f'ecg_lead_{lead_index + 1}_image.png', format='png', cmap='gray')
    plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a00b4a5b0866> in <cell line: 18>()
#      42     # Save the figure as a gray scale image
#      43     plt.tight_layout()
# ---> 44     plt.savefig(f'ecg_lead_{lead_index + 1}_image.png', format='png', cmap='gray')
#      45     plt.close()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data from the .asc file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"  
ecg_data = np.loadtxt(file_path)


# Extract the first column
first_column = ecg_data[:, 0]

# Generate time values for the x-axis
time_values = np.arange(0, len(first_column) * 10, 10)

# Plot the ECG wave for the first lead
plt.plot(time_values, first_column)



# Customize the plot
plt.title('ECG Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Adjust figure size and DPI to avoid the ValueError
fig = plt.gcf()
fig.set_size_inches(200, 20)  # Adjust the size as needed
fig.set_dpi(100)  # Adjust the DPI as needed

# Show the plot
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Define the time axis (assuming 2 ms intervals)
time_axis = np.arange(0, 10, 0.002)

# Create subplots for each lead
fig, axs = plt.subplots(8, 1, figsize=(10, 12), sharex=True)

# Plot each lead
for lead_index in range(ecg_data.shape[1]):
    axs[lead_index].plot(time_axis, ecg_data[:, lead_index], color='black')
    axs[lead_index].set_ylabel(f'Lead {lead_index + 1}')

# Set common x-axis label
axs[-1].set_xlabel('Time (s)')

# Set x-axis markers every 500 ms
marker_positions = np.arange(0, 10, 0.5)
plt.xticks(marker_positions)

# Display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Given ECG data (replace with your actual data)
ecg_data = np.array(ecg_data)

# Create a time axis (x-axis) in milliseconds
time_axis = np.arange(0, 10_000, 2)  # 5000 rows, 2 ms intervals

# Plot each lead recording
for lead_idx in range(ecg_data.shape[1]):
    plt.figure(figsize=(6, 4))  # Adjust figure size as needed
    plt.plot(time_axis, ecg_data[:, lead_idx], color='black')
    plt.xlabel('Time (ms)')
    plt.ylabel('Amplitude')
    plt.title(f'Lead {lead_idx + 1}')
    plt.grid(True)
    plt.savefig(f'lead_{lead_idx + 1}.png', dpi=300, bbox_inches='tight')  # Save each plot as an image
    plt.close()

print("Plots saved as 'lead_1.png', 'lead_2.png', ..., 'lead_8.png'")
# Out:
# Plots saved as 'lead_1.png', 'lead_2.png', ..., 'lead_8.png'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Remove the first 250 and last 250 rows from each column
ecg_data_trimmed = ecg_data[300:-200, :]

# Define the time axis (assuming 2 ms intervals)
time_axis_trimmed = np.arange(0, 10 - (0.002 * 500), 0.002)

# Create subplots for each lead
fig, axs = plt.subplots(8, 1, figsize=(10, 12), sharex=True)

# Plot each lead for trimmed data
for lead_index in range(ecg_data_trimmed.shape[1]):
    axs[lead_index].plot(time_axis_trimmed, ecg_data_trimmed[:, lead_index], color='black')
    axs[lead_index].set_ylabel(f'Lead {lead_index + 1}')

# Set common x-axis label
axs[-1].set_xlabel('Time (s)')

# Set x-axis markers every 500 ms
marker_positions = np.arange(0, 10 - (0.5), 0.5)
plt.xticks(marker_positions)

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 9 sec long 9 plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Remove the first 250 and last 250 rows from each column
ecg_data_trimmed = ecg_data[300:-200, :]

# Define the time axis for trimmed data (assuming 2 ms intervals)
time_axis_trimmed = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.002)

# Number of 1-second intervals (500 rows per interval)
num_intervals = ecg_data_trimmed.shape[0] // 500

# Create subplots for each lead and each 1-second interval
fig, axs = plt.subplots(num_intervals, 8, figsize=(15, 2 * num_intervals), sharex=True, sharey=True)

# Plot each lead for each 1-second interval
for interval_index in range(num_intervals):
    start_row = interval_index * 500
    end_row = start_row + 500

    for lead_index in range(ecg_data_trimmed.shape[1]):
        axs[interval_index, lead_index].plot(
            time_axis_trimmed[start_row:end_row],
            ecg_data_trimmed[start_row:end_row, lead_index],
            color='black'
        )
        axs[interval_index, lead_index].set_ylabel(f'Lead {lead_index + 1}')

    axs[interval_index, 0].set_title(f'Interval {interval_index + 1}')

# Set common x-axis label
axs[-1, 4].set_xlabel('Time (s)')

# Set x-axis markers every 500 ms
marker_positions = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.5)
plt.xticks(marker_positions)

# Display the plots
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the ECG data from the file
file_path = "datasets/deepfake_ecg/from_006_chck_2500_150k_filtered_all_normals_121977/0.asc"
ecg_data = np.loadtxt(file_path)

# Remove the first 250 and last 250 rows from each column
ecg_data_trimmed = ecg_data[300:-200, :]

# Define the time axis for trimmed data (assuming 2 ms intervals)
time_axis_trimmed = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.002)

# Number of 3-second intervals (1500 rows per interval)
num_intervals = ecg_data_trimmed.shape[0] // 1500

# Create a figure and axis for each lead
fig, axs = plt.subplots(8, num_intervals, figsize=(15, 15), sharex=True, sharey=True)

# Plot each lead for each 3-second interval in the same image
for lead_index in range(ecg_data_trimmed.shape[1]):
    for interval_index in range(num_intervals):
        start_row = interval_index * 1500
        end_row = start_row + 1500

        ax = axs[lead_index, interval_index]
        ax.plot(
            time_axis_trimmed[start_row:end_row],
            ecg_data_trimmed[start_row:end_row, lead_index],
            color='black'
        )
        ax.set_title(f'Lead {lead_index + 1}, Interval {interval_index + 1}')
        ax.set_ylabel('Amplitude')

# Set common x-axis label
axs[-1, 0].set_xlabel('Time (s)')

# Set x-axis markers every 500 ms
marker_positions = np.arange(0, (ecg_data_trimmed.shape[0] * 0.002), 0.5)
plt.xticks(marker_positions)

# Save the figure as a gray scale image
plt.tight_layout()
plt.savefig('ecg_image_combined.png', format='png', cmap='gray')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-061aa3c2e6ed> in <cell line: 44>()
#      42 # Save the figure as a gray scale image
#      43 plt.tight_layout()
# ---> 44 plt.savefig('ecg_image_combined.png', format='png', cmap='gray')
#      45 plt.close()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#    1021 def savefig(*args, **kwargs):
#    1022     fig = gcf()
# -> 1023     res = fig.savefig(*args, **kwargs)
#    1024     fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1025     return res
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3341                         ax.patch._cm_set(facecolor='none', edgecolor='none'))
#    3342
# -> 3343             self.canvas.print_figure(fname, **kwargs)
#    3344
# ...

# %%
# !pip install vit_pytorch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.4 MB/s eta 0:00:00
# ...

# %%
import torch
from vit_pytorch.deepvit import DeepViT

v = DeepViT(
    image_size = 256,
    patch_size = 32,
    num_classes = 1000,
    dim = 1024,
    depth = 6,
    heads = 16,
    mlp_dim = 2048,
    dropout = 0.1,
    emb_dropout = 0.1
)

# %%
import torch
from vit_pytorch.deepvit import DeepViT

class DeepViTRegression(torch.nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        # Create DeepViT model with given arguments
        self.vit = DeepViT(**kwargs)
        # Modify the output layer for regression
        self.regression_head = torch.nn.Linear(kwargs['dim'], 1)

    def forward(self, x):
        # Forward pass through DeepViT
        x = self.vit(x)
        # Apply the regression head
        x = self.regression_head(x)
        return x

# Example usage
v_regression = DeepViTRegression(
    image_size=256,
    patch_size=32,
    dim=1024,
    depth=6,
    heads=16,
    mlp_dim=2048,
    dropout=0.1,
    emb_dropout=0.1
)

# Generate random image tensor
img = torch.randn(1, 3, 256, 256)

# Forward pass for regression task
predictions = v_regression(img)  # Output will be a single value for regression
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-250c0868e88a> in <cell line: 20>()
#      18
#      19 # Example usage
# ---> 20 v_regression = DeepViTRegression(
#      21     image_size=256,
#      22     patch_size=32,
#
# <ipython-input-7-250c0868e88a> in __init__(self, **kwargs)
#       6         super().__init__()
#       7         # Create DeepViT model with given arguments
# ----> 8         self.vit = DeepViT(**kwargs)
#       9         # Modify the output layer for regression
#      10         self.regression_head = torch.nn.Linear(kwargs['dim'], 1)
#
# TypeError: DeepViT.__init__() missing 1 required keyword-only argument: 'num_classes'

# %%
import torch
from vit_pytorch.deepvit import DeepViT

class DeepViTRegression(torch.nn.Module):
    def __init__(self, **kwargs):
        super().__init__()
        # Exclude 'num_classes' from the arguments passed to DeepViT
        self.vit = DeepViT(num_classes=0, **kwargs)
        # Modify the output layer for regression
        self.regression_head = torch.nn.Linear(kwargs['dim'], 1)

    def forward(self, x):
        # Forward pass through DeepViT
        x = self.vit(x)
        # Take the mean across the patch dimension
        x = torch.mean(x, dim=1)
        # Apply the regression head
        x = self.regression_head(x)
        return x

# Example usage
v_regression = DeepViTRegression(
    image_size=256,
    patch_size=32,
    dim=1024,
    depth=6,
    heads=16,
    mlp_dim=2048,
    dropout=0.1,
    emb_dropout=0.1
)

# Generate random image tensor
img = torch.randn(1, 3, 256, 256)

# Forward pass for regression task
predictions = v_regression(img)  # Output will be a single value for regression
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-834c7acbad3f> in <cell line: 37>()
#      35
#      36 # Forward pass for regression task
# ---> 37 predictions = v_regression(img)  # Output will be a single value for regression
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# ...
