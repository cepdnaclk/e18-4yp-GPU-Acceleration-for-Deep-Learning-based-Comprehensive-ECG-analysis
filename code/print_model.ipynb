# %%
from models.Inception1D import Inception1d
from torchinfo import summary  # pip install torchinfo
from torchviz import make_dot
import torch
import os

model = Inception1d(num_classes=1, input_channels=8, use_residual=True, ps_head=0.5, lin_ftrs_head=[128], kernel_size=40)
summary(model, input_size=(32, 8, 5000), depth=11)
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# Inception1d                                        [32, 1]                   --
# ├─Sequential: 1-1                                  [32, 1]                   --
# │    └─InceptionBackbone: 2-1                      [32, 128, 5000]           --
# │    │    └─ModuleList: 3-3                        --                        (recursive)
# │    │    │    └─InceptionBlock1d: 4-1             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-1                  [32, 32, 5000]            256
# │    │    │    │    └─ModuleList: 5-2              --                        --
# │    │    │    │    │    └─Conv1d: 6-1             [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-2             [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-3             [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-3              [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-4          [32, 8, 5000]             --
# │    │    │    │    │    └─Conv1d: 6-5             [32, 32, 5000]            256
# │    │    │    │    └─Sequential: 5-4              [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-6        [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-7               [32, 128, 5000]           --
# │    │    │    └─InceptionBlock1d: 4-2             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-5                  [32, 32, 5000]            4,096
# │    │    │    │    └─ModuleList: 5-6              --                        --
# │    │    │    │    │    └─Conv1d: 6-8             [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-9             [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-10            [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-7              [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-11         [32, 128, 5000]           --
# │    │    │    │    │    └─Conv1d: 6-12            [32, 32, 5000]            4,096
# │    │    │    │    └─Sequential: 5-8              [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-13       [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-14              [32, 128, 5000]           --
# │    │    │    └─InceptionBlock1d: 4-3             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-9                  [32, 32, 5000]            4,096
# │    │    │    │    └─ModuleList: 5-10             --                        --
# │    │    │    │    │    └─Conv1d: 6-15            [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-16            [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-17            [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-11             [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-18         [32, 128, 5000]           --
# │    │    │    │    │    └─Conv1d: 6-19            [32, 32, 5000]            4,096
# │    │    │    │    └─Sequential: 5-12             [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-20       [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-21              [32, 128, 5000]           --
# │    │    └─ModuleList: 3-4                        --                        (recursive)
# │    │    │    └─Shortcut1d: 4-4                   [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-13                 [32, 128, 5000]           1,024
# │    │    │    │    └─BatchNorm1d: 5-14            [32, 128, 5000]           256
# │    │    │    │    └─ReLU: 5-15                   [32, 128, 5000]           --
# │    │    └─ModuleList: 3-3                        --                        (recursive)
# │    │    │    └─InceptionBlock1d: 4-5             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-16                 [32, 32, 5000]            4,096
# │    │    │    │    └─ModuleList: 5-17             --                        --
# │    │    │    │    │    └─Conv1d: 6-22            [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-23            [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-24            [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-18             [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-25         [32, 128, 5000]           --
# │    │    │    │    │    └─Conv1d: 6-26            [32, 32, 5000]            4,096
# │    │    │    │    └─Sequential: 5-19             [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-27       [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-28              [32, 128, 5000]           --
# │    │    │    └─InceptionBlock1d: 4-6             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-20                 [32, 32, 5000]            4,096
# │    │    │    │    └─ModuleList: 5-21             --                        --
# │    │    │    │    │    └─Conv1d: 6-29            [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-30            [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-31            [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-22             [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-32         [32, 128, 5000]           --
# │    │    │    │    │    └─Conv1d: 6-33            [32, 32, 5000]            4,096
# │    │    │    │    └─Sequential: 5-23             [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-34       [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-35              [32, 128, 5000]           --
# │    │    │    └─InceptionBlock1d: 4-7             [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-24                 [32, 32, 5000]            4,096
# │    │    │    │    └─ModuleList: 5-25             --                        --
# │    │    │    │    │    └─Conv1d: 6-36            [32, 32, 5000]            39,936
# │    │    │    │    │    └─Conv1d: 6-37            [32, 32, 5000]            19,456
# │    │    │    │    │    └─Conv1d: 6-38            [32, 32, 5000]            9,216
# │    │    │    │    └─Sequential: 5-26             [32, 32, 5000]            --
# │    │    │    │    │    └─MaxPool1d: 6-39         [32, 128, 5000]           --
# │    │    │    │    │    └─Conv1d: 6-40            [32, 32, 5000]            4,096
# │    │    │    │    └─Sequential: 5-27             [32, 128, 5000]           --
# │    │    │    │    │    └─BatchNorm1d: 6-41       [32, 128, 5000]           256
# │    │    │    │    │    └─ReLU: 6-42              [32, 128, 5000]           --
# │    │    └─ModuleList: 3-4                        --                        (recursive)
# │    │    │    └─Shortcut1d: 4-8                   [32, 128, 5000]           --
# │    │    │    │    └─Conv1d: 5-28                 [32, 128, 5000]           16,384
# │    │    │    │    └─BatchNorm1d: 5-29            [32, 128, 5000]           256
# │    │    │    │    └─ReLU: 5-30                   [32, 128, 5000]           --
# │    └─Sequential: 2-2                             [32, 1]                   --
# │    │    └─AdaptiveConcatPool1d: 3-5              [32, 256, 1]              --
# │    │    │    └─AdaptiveMaxPool1d: 4-9            [32, 128, 1]              --
# │    │    │    └─AdaptiveAvgPool1d: 4-10           [32, 128, 1]              --
# │    │    └─Flatten: 3-6                           [32, 256]                 --
# │    │    └─BatchNorm1d: 3-7                       [32, 256]                 512
# │    │    └─Dropout: 3-8                           [32, 256]                 --
# │    │    └─Linear: 3-9                            [32, 128]                 32,896
# │    │    └─ReLU: 3-10                             [32, 128]                 --
# │    │    └─BatchNorm1d: 3-11                      [32, 128]                 256
# │    │    └─Dropout: 3-12                          [32, 128]                 --
# │    │    └─Linear: 3-13                           [32, 1]                   129
# ====================================================================================================
# Total params: 506,369
# Trainable params: 506,369
# Non-trainable params: 0
# Total mult-adds (G): 75.29
# ====================================================================================================
# Input size (MB): 5.12
# Forward/backward pass size (MB): 2867.33
# Params size (MB): 2.03
# Estimated Total Size (MB): 2874.48
# ====================================================================================================
